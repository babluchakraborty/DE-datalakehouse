# %% [markdown]
# #AutoLoader

# %% [markdown]
# #####Setup

# %%
base_dir = 'abfss://landingzone@stavikaslakefreetrail.dfs.core.windows.net/Autoloader/PR_Demo'

# %% [markdown]
# #####1. Verify you can access the invoices directory

# %%
# %fs ls abfss://landingzone@stavikaslakefreetrail.dfs.core.windows.net/Autoloader/PR_Demo/Invoices/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>abfss://landingzone@stavikaslakefreetrail.dfs.core.windows.net/Autoloader/PR_Demo/Invoices/invoices_01-06-2022.csv</td><td>invoices_01-06-2022.csv</td><td>43357</td><td>1726743279000</td></tr><tr><td>abfss://landingzone@stavikaslakefreetrail.dfs.core.windows.net/Autoloader/PR_Demo/Invoices/invoices_02-06-2022.csv</td><td>invoices_02-06-2022.csv</td><td>8644</td><td>1726743279000</td></tr><tr><td>abfss://landingzone@stavikaslakefreetrail.dfs.core.windows.net/Autoloader/PR_Demo/Invoices/invoices_03-06-2022.csv</td><td>invoices_03-06-2022.csv</td><td>735</td><td>1726743279000</td></tr></tbody></table></div>

# %% [markdown]
# Lets have a look at autoloader in action<br>
# Do not leave the below cell running, terminate the query the moment you dont need it

# %%
source_df = (spark.readStream
                      .format("cloudFiles")
                      .option("cloudFiles.format", "csv")  
                      .option("header", "true") 
                      .option("timestampFormat","d-M-y H.m")                  
                      .option("cloudFiles.schemaLocation", f"{base_dir}/chekpoint/invoices_schema")
                      .option("cloudFiles.inferColumnTypes", "true")
                      .option("cloudFiles.schemaHints", "InvoiceNo string, CustomerID string")
                      .load(f"{base_dir}/Invoices")
  )

display(source_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>InvoiceNo</th><th>StockCode</th><th>Description</th><th>Quantity</th><th>InvoiceDate</th><th>UnitPrice</th><th>CustomerID</th><th>_rescued_data</th></tr></thead><tbody><tr><td>565231</td><td>47504K</td><td>ENGLISH ROSE GARDEN SECATEURS</td><td>1</td><td>2022-06-01T09:26:00Z</td><td>3.29</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>47566</td><td>PARTY BUNTING</td><td>2</td><td>2022-06-01T09:26:00Z</td><td>10.79</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>51014A</td><td>FEATHER PEN,HOT PINK</td><td>2</td><td>2022-06-01T09:26:00Z</td><td>0.83</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>72760B</td><td>VINTAGE CREAM 3 BASKET CAKE STAND</td><td>1</td><td>2022-06-01T09:26:00Z</td><td>20.79</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>72807A</td><td>SET/3 ROSE CANDLE IN JEWELLED BOX</td><td>1</td><td>2022-06-01T09:26:00Z</td><td>8.29</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>72807C</td><td>SET/3 VANILLA SCENTED CANDLE IN BOX</td><td>1</td><td>2022-06-01T09:26:00Z</td><td>8.29</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>82551</td><td>LAUNDRY 15C METAL SIGN</td><td>1</td><td>2022-06-01T09:26:00Z</td><td>2.46</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>82567</td><td>AIRLINE LOUNGE,METAL SIGN</td><td>1</td><td>2022-06-01T09:26:00Z</td><td>1.63</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>82578</td><td>KITCHEN METAL SIGN</td><td>1</td><td>2022-06-01T09:26:00Z</td><td>1.25</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>82580</td><td>BATHROOM METAL SIGN</td><td>1</td><td>2022-06-01T09:26:00Z</td><td>1.25</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>82581</td><td>TOILET METAL SIGN</td><td>1</td><td>2022-06-01T09:26:00Z</td><td>1.25</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>84032A</td><td>CHARLIE+LOLA PINK HOT WATER BOTTLE</td><td>2</td><td>2022-06-01T09:26:00Z</td><td>3.29</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>84380</td><td>SET OF 3 BUTTERFLY COOKIE CUTTERS</td><td>3</td><td>2022-06-01T09:26:00Z</td><td>2.46</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>84510A</td><td>SET OF 4 ENGLISH ROSE COASTERS</td><td>1</td><td>2022-06-01T09:26:00Z</td><td>2.46</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>84659A</td><td>WHITE TRAVEL ALARM CLOCK</td><td>1</td><td>2022-06-01T09:26:00Z</td><td>2.46</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>84912B</td><td>GREEN ROSE WASHBAG</td><td>1</td><td>2022-06-01T09:26:00Z</td><td>3.29</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>84946</td><td>ANTIQUE SILVER T-LIGHT GLASS</td><td>6</td><td>2022-06-01T09:26:00Z</td><td>2.46</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>84947</td><td>ANTIQUE SILVER TEA GLASS ENGRAVED</td><td>6</td><td>2022-06-01T09:26:00Z</td><td>2.46</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>84978</td><td>HANGING HEART JAR T-LIGHT HOLDER</td><td>12</td><td>2022-06-01T09:26:00Z</td><td>2.46</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>85049H</td><td>URBAN BLACK RIBBONS </td><td>3</td><td>2022-06-01T09:26:00Z</td><td>0.83</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>85087</td><td>CANDY SPOT CUSHION COVER</td><td>1</td><td>2022-06-01T09:26:00Z</td><td>3.29</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>85093</td><td>CANDY SPOT EGG WARMER HARE</td><td>1</td><td>2022-06-01T09:26:00Z</td><td>0.83</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>85123A</td><td>WHITE HANGING HEART T-LIGHT HOLDER</td><td>4</td><td>2022-06-01T09:26:00Z</td><td>2.95</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>85132C</td><td>CHARLIE AND LOLA FIGURES TINS</td><td>2</td><td>2022-06-01T09:26:00Z</td><td>5.79</td><td>null</td><td>null</td></tr><tr><td>565232</td><td>20840</td><td>FRENCH FLORAL CUSHION COVER </td ...

# %% [markdown]
# #####2. Ingest data into invoices_raw table using spark streaming api

# %%
#create a managed table in bronze schema for autoloader ingestion
spark.sql("drop table if exists  psl_salesdev.bronze.invoices_raw")
spark.sql("""
          CREATE TABLE IF NOT EXISTS psl_salesdev.bronze.invoices_raw(
        InvoiceNo string COMMENT 'Invoice number',
        StockCode string,
        Description string,
        Quantity int,
        InvoiceDate timestamp,
        UnitPrice double,
        CustomerID string)""")
# Out:
# DataFrame[]

# %%
def ingest():
  source_df = (spark.readStream
                      .format("cloudFiles")
                      .option("cloudFiles.format", "csv")  
                      .option("header", "true") 
                      .option("timestampFormat","d-M-y H.m")                  
                      .option("cloudFiles.schemaLocation", f"{base_dir}/chekpoint/invoices_schema")
                      .option("cloudFiles.inferColumnTypes", "true")
                      .option("cloudFiles.schemaHints", "InvoiceNo string, CustomerID string")
                      .load(f"{base_dir}/Invoices")
  )

  write_query = (source_df.writeStream
                          .format("delta")
                          .option("checkpointLocation", f"{base_dir}/chekpoint/Invoices")
                          .option("mergeSchema", "true")
                          .outputMode("append")                          
                          .trigger(availableNow = True)
                          .toTable("psl_salesdev.bronze.invoices_raw")
  )

ingest()

# %% [markdown]
# #####3. Check the records after ingestion

# %%
# %sql
SELECT * FROM psl_salesdev.bronze.invoices_raw
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>InvoiceNo</th><th>StockCode</th><th>Description</th><th>Quantity</th><th>InvoiceDate</th><th>UnitPrice</th><th>CustomerID</th><th>_rescued_data</th></tr></thead><tbody><tr><td>565231</td><td>47504K</td><td>ENGLISH ROSE GARDEN SECATEURS</td><td>1</td><td>2022-06-01T09:26:00Z</td><td>3.29</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>47566</td><td>PARTY BUNTING</td><td>2</td><td>2022-06-01T09:26:00Z</td><td>10.79</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>51014A</td><td>FEATHER PEN,HOT PINK</td><td>2</td><td>2022-06-01T09:26:00Z</td><td>0.83</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>72760B</td><td>VINTAGE CREAM 3 BASKET CAKE STAND</td><td>1</td><td>2022-06-01T09:26:00Z</td><td>20.79</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>72807A</td><td>SET/3 ROSE CANDLE IN JEWELLED BOX</td><td>1</td><td>2022-06-01T09:26:00Z</td><td>8.29</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>72807C</td><td>SET/3 VANILLA SCENTED CANDLE IN BOX</td><td>1</td><td>2022-06-01T09:26:00Z</td><td>8.29</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>82551</td><td>LAUNDRY 15C METAL SIGN</td><td>1</td><td>2022-06-01T09:26:00Z</td><td>2.46</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>82567</td><td>AIRLINE LOUNGE,METAL SIGN</td><td>1</td><td>2022-06-01T09:26:00Z</td><td>1.63</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>82578</td><td>KITCHEN METAL SIGN</td><td>1</td><td>2022-06-01T09:26:00Z</td><td>1.25</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>82580</td><td>BATHROOM METAL SIGN</td><td>1</td><td>2022-06-01T09:26:00Z</td><td>1.25</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>82581</td><td>TOILET METAL SIGN</td><td>1</td><td>2022-06-01T09:26:00Z</td><td>1.25</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>84032A</td><td>CHARLIE+LOLA PINK HOT WATER BOTTLE</td><td>2</td><td>2022-06-01T09:26:00Z</td><td>3.29</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>84380</td><td>SET OF 3 BUTTERFLY COOKIE CUTTERS</td><td>3</td><td>2022-06-01T09:26:00Z</td><td>2.46</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>84510A</td><td>SET OF 4 ENGLISH ROSE COASTERS</td><td>1</td><td>2022-06-01T09:26:00Z</td><td>2.46</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>84659A</td><td>WHITE TRAVEL ALARM CLOCK</td><td>1</td><td>2022-06-01T09:26:00Z</td><td>2.46</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>84912B</td><td>GREEN ROSE WASHBAG</td><td>1</td><td>2022-06-01T09:26:00Z</td><td>3.29</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>84946</td><td>ANTIQUE SILVER T-LIGHT GLASS</td><td>6</td><td>2022-06-01T09:26:00Z</td><td>2.46</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>84947</td><td>ANTIQUE SILVER TEA GLASS ENGRAVED</td><td>6</td><td>2022-06-01T09:26:00Z</td><td>2.46</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>84978</td><td>HANGING HEART JAR T-LIGHT HOLDER</td><td>12</td><td>2022-06-01T09:26:00Z</td><td>2.46</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>85049H</td><td>URBAN BLACK RIBBONS </td><td>3</td><td>2022-06-01T09:26:00Z</td><td>0.83</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>85087</td><td>CANDY SPOT CUSHION COVER</td><td>1</td><td>2022-06-01T09:26:00Z</td><td>3.29</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>85093</td><td>CANDY SPOT EGG WARMER HARE</td><td>1</td><td>2022-06-01T09:26:00Z</td><td>0.83</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>85123A</td><td>WHITE HANGING HEART T-LIGHT HOLDER</td><td>4</td><td>2022-06-01T09:26:00Z</td><td>2.95</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>85132C</td><td>CHARLIE AND LOLA FIGURES TINS</td><td>2</td><td>2022-06-01T09:26:00Z</td><td>5.79</td><td>null</td><td>null</td></tr><tr><td>565232</td><td>20840</td><td>FRENCH FLORAL CUSHION COVER </td ...

# %%
# %sql
DESCRIBE psl_salesdev.bronze.invoices_raw
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>InvoiceNo</td><td>string</td><td>Invoice number</td></tr><tr><td>StockCode</td><td>string</td><td>null</td></tr><tr><td>Description</td><td>string</td><td>null</td></tr><tr><td>Quantity</td><td>int</td><td>null</td></tr><tr><td>InvoiceDate</td><td>timestamp</td><td>null</td></tr><tr><td>UnitPrice</td><td>double</td><td>null</td></tr><tr><td>CustomerID</td><td>string</td><td>null</td></tr><tr><td>_rescued_data</td><td>string</td><td>null</td></tr></tbody></table></div>

# %% [markdown]
# #####4. Ingest some more data into the invoices directory which comes with an additional column

# %%
# %fs cp abfss://landingzone@stavikaslakefreetrail.dfs.core.windows.net/Autoloader/PR_Demo/invoices_2021.csv abfss://landingzone@stavikaslakefreetrail.dfs.core.windows.net/Autoloader/PR_Demo/Invoices/
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res1: Boolean = true
# </div>

# %% [markdown]
# #####5. Ingest with a retry

# %%
ingest()

# %% [markdown]
# #####6. Check the data

# %%
# %sql
SELECT * FROM psl_salesdev.bronze.invoices_raw
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>InvoiceNo</th><th>StockCode</th><th>Description</th><th>Quantity</th><th>InvoiceDate</th><th>UnitPrice</th><th>CustomerID</th><th>_rescued_data</th><th>Country</th></tr></thead><tbody><tr><td>565231</td><td>47504K</td><td>ENGLISH ROSE GARDEN SECATEURS</td><td>1</td><td>2022-06-01T09:26:00Z</td><td>3.29</td><td>null</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>47566</td><td>PARTY BUNTING</td><td>2</td><td>2022-06-01T09:26:00Z</td><td>10.79</td><td>null</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>51014A</td><td>FEATHER PEN,HOT PINK</td><td>2</td><td>2022-06-01T09:26:00Z</td><td>0.83</td><td>null</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>72760B</td><td>VINTAGE CREAM 3 BASKET CAKE STAND</td><td>1</td><td>2022-06-01T09:26:00Z</td><td>20.79</td><td>null</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>72807A</td><td>SET/3 ROSE CANDLE IN JEWELLED BOX</td><td>1</td><td>2022-06-01T09:26:00Z</td><td>8.29</td><td>null</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>72807C</td><td>SET/3 VANILLA SCENTED CANDLE IN BOX</td><td>1</td><td>2022-06-01T09:26:00Z</td><td>8.29</td><td>null</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>82551</td><td>LAUNDRY 15C METAL SIGN</td><td>1</td><td>2022-06-01T09:26:00Z</td><td>2.46</td><td>null</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>82567</td><td>AIRLINE LOUNGE,METAL SIGN</td><td>1</td><td>2022-06-01T09:26:00Z</td><td>1.63</td><td>null</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>82578</td><td>KITCHEN METAL SIGN</td><td>1</td><td>2022-06-01T09:26:00Z</td><td>1.25</td><td>null</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>82580</td><td>BATHROOM METAL SIGN</td><td>1</td><td>2022-06-01T09:26:00Z</td><td>1.25</td><td>null</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>82581</td><td>TOILET METAL SIGN</td><td>1</td><td>2022-06-01T09:26:00Z</td><td>1.25</td><td>null</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>84032A</td><td>CHARLIE+LOLA PINK HOT WATER BOTTLE</td><td>2</td><td>2022-06-01T09:26:00Z</td><td>3.29</td><td>null</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>84380</td><td>SET OF 3 BUTTERFLY COOKIE CUTTERS</td><td>3</td><td>2022-06-01T09:26:00Z</td><td>2.46</td><td>null</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>84510A</td><td>SET OF 4 ENGLISH ROSE COASTERS</td><td>1</td><td>2022-06-01T09:26:00Z</td><td>2.46</td><td>null</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>84659A</td><td>WHITE TRAVEL ALARM CLOCK</td><td>1</td><td>2022-06-01T09:26:00Z</td><td>2.46</td><td>null</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>84912B</td><td>GREEN ROSE WASHBAG</td><td>1</td><td>2022-06-01T09:26:00Z</td><td>3.29</td><td>null</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>84946</td><td>ANTIQUE SILVER T-LIGHT GLASS</td><td>6</td><td>2022-06-01T09:26:00Z</td><td>2.46</td><td>null</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>84947</td><td>ANTIQUE SILVER TEA GLASS ENGRAVED</td><td>6</td><td>2022-06-01T09:26:00Z</td><td>2.46</td><td>null</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>84978</td><td>HANGING HEART JAR T-LIGHT HOLDER</td><td>12</td><td>2022-06-01T09:26:00Z</td><td>2.46</td><td>null</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>85049H</td><td>URBAN BLACK RIBBONS </td><td>3</td><td>2022-06-01T09:26:00Z</td><td>0.83</td><td>null</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>85087</td><td>CANDY SPOT CUSHION COVER</td><td>1</td><td>2022-06-01T09:26:00Z</td><td>3.29</td><td>null</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>85093</td><td>CANDY SPOT EGG WARMER HARE</td><td>1</td><td>2022-06-01T09:26:00Z</td><td>0.83</td><td>null</td><td>null</td><td>null</td></tr><tr><td>565231</td><td>85123A</td><td>WHITE HANGING HEART T-LIGHT HOLDER</td><td>4 ...

# %%
# %sql
DESCRIBE psl_salesdev.bronze.invoices_raw
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>InvoiceNo</td><td>string</td><td>Invoice number</td></tr><tr><td>StockCode</td><td>string</td><td>null</td></tr><tr><td>Description</td><td>string</td><td>null</td></tr><tr><td>Quantity</td><td>int</td><td>null</td></tr><tr><td>InvoiceDate</td><td>timestamp</td><td>null</td></tr><tr><td>UnitPrice</td><td>double</td><td>null</td></tr><tr><td>CustomerID</td><td>string</td><td>null</td></tr><tr><td>_rescued_data</td><td>string</td><td>null</td></tr><tr><td>Country</td><td>string</td><td>null</td></tr></tbody></table></div>

# %% [markdown]
# #####7. Ingest some more records with potential bad records

# %%
# %fs cp abfss://landingzone@stavikaslakefreetrail.dfs.core.windows.net/Autoloader/PR_Demo/invoices_2022.csv abfss://landingzone@stavikaslakefreetrail.dfs.core.windows.net/Autoloader/PR_Demo/Invoices/
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res2: Boolean = true
# </div>

# %%
ingest()

# %% [markdown]
# #####8. Check the rescued data

# %%
# %sql
SELECT * FROM psl_salesdev.bronze.invoices_raw where _rescued_data is not null
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>InvoiceNo</th><th>StockCode</th><th>Description</th><th>Quantity</th><th>InvoiceDate</th><th>UnitPrice</th><th>CustomerID</th><th>_rescued_data</th><th>Country</th></tr></thead><tbody><tr><td>536639</td><td>22822</td><td>CREAM WALL PLANTER HEART SHAPED</td><td>2</td><td>null</td><td>5.95</td><td>15111</td><td>{"InvoiceDate":"30-30-2022 11.45","_file_path":"abfss://landingzone@stavikaslakefreetrail.dfs.core.windows.net/Autoloader/PR_Demo/Invoices/invoices_2022.csv"}</td><td>United Kingdom</td></tr></tbody></table></div>

# %% [markdown]
# &copy; Polestar Solutions and Services India Pvt. Ltd. All rights reserved.<br/>
